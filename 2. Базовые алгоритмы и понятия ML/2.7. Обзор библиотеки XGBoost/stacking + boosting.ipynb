# %% [markdown]
# # Stacking + Boosting

# %%
# https://www.kaggle.com/c/titanic

# %%
import sklearn
import pandas as pd

# %%
# Загружаем данные из файлов
train = pd.read_csv('./titanic/train.csv')
test = pd.read_csv('./titanic/test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Предобработка данных

# %%
# Заполняем пропуски в данных медианными 
# значениями факторов на обучающей выборке
train_median = train.median()
train_imp = train.fillna(train_median)
test_imp = test.fillna(train_median)

# %%
train_imp.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Бинаризуем категориальные признаки
CATEGORY_COL = ['Sex', 'Pclass', 'Embarked']
train_dummies = pd.get_dummies(train_imp, columns=CATEGORY_COL, drop_first=True)
test_dummies = pd.get_dummies(test_imp, columns=CATEGORY_COL, drop_first=True)

# %%
train_dummies.head()
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
#
#     Age  SibSp  Parch            Ticket     Fare Cabin  Sex_male  Pclass_2  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN         1         0
# 1  38.0      1      0          PC 17599  71.2833   C85         0         0
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN         0         0
# 3  35.0      1      0            113803  53.1000  C123         0         0
# 4  35.0      0      0            373450   8.0500   NaN         1         0
#
#    Pclass_3  Embarked_Q  Embarked_S
# 0         1           0           1
# 1         0           0           0
# 2         1           0           1
# 3         0           0           1
# 4         1           0           1

# %%
# Удаляем лишние столбцы
DROP_COL = ['PassengerId', 'Name', 'Ticket', 'Cabin']
TARGET_COL = 'Survived'
X_train = train_dummies.drop(DROP_COL + [TARGET_COL], axis=1)
y_train = train_dummies[TARGET_COL]
X_test = test_dummies.drop(DROP_COL, axis=1)

# %% [markdown]
# ## Тюнинг моделей. Зададим сетку параметров

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()

params_grid = { # параметры для RandomForest, которые будем тюнить
    'n_estimators': [1, 2, 3, 10, 35],
    'min_samples_split': [2, 5, 10]
}

# %% [markdown]
# ## Тюнинг моделей. Способ 1
# "В лоб"

# %%
from sklearn.metrics import roc_auc_score

kf = KFold(n_splits=4, shuffle=True) # Всегда делайте shuffle если обучаете не на последовательных данных!

# Переберём все возможные комбинации параметров
params = [{}]
for parameter_name in params_grid:
    parameter_values = params_grid[parameter_name]
    new_params = []
    for value in parameter_values:    
        for param in params:
            updated_param = param.copy()
            updated_param[parameter_name] = value
            new_params.append(updated_param)
    params = new_params
    
# Выберем из всех вариаций параметров наилучшую
best_params = {}
best_auc = 0
for param in params:
    print(('Training RandomForest with params: ', param))
    clf.set_params(**param)
    
    fold_aucs = []
    for train_idx, test_idx in kf.split(X_train):
        X_train_fold, X_test_fold = X_train.iloc[train_idx], X_train.iloc[test_idx]
        y_train_fold, y_test_fold = y_train.iloc[train_idx], y_train.iloc[test_idx]
        clf.fit(X_train_fold, y_train_fold)
        preds = clf.predict_proba(X_test_fold)
        auc = roc_auc_score(y_test_fold, preds[:, 1])
        fold_aucs.append(auc)
    auc = np.mean(fold_aucs)
    print(('AUC: ', auc))
    if auc > best_auc:
        best_params = param
        best_auc = auc

print('Best params:')
best_params
# Out:
# ('Training RandomForest with params: ', {'n_estimators': 1, 'min_samples_split': 2})
# ('AUC: ', 0.72962444212968747)
# ('Training RandomForest with params: ', {'n_estimators': 2, 'min_samples_split': 2})
# ('AUC: ', 0.77813179559758439)
# ('Training RandomForest with params: ', {'n_estimators': 3, 'min_samples_split': 2})
# ('AUC: ', 0.84708799048078298)
# ('Training RandomForest with params: ', {'n_estimators': 10, 'min_samples_split': 2})
# ('AUC: ', 0.85378844126001185)
# ('Training RandomForest with params: ', {'n_estimators': 35, 'min_samples_split': 2})
# ('AUC: ', 0.85334302379977534)
# ('Training RandomForest with params: ', {'n_estimators': 1, 'min_samples_split': 5})
# ('AUC: ', 0.7535676621922629)
# ('Training RandomForest with params: ', {'n_estimators': 2, 'min_samples_split': 5})
# ('AUC: ', 0.81327471072138824)
# ('Training RandomForest with params: ', {'n_estimators': 3, 'min_samples_split': 5})
# ('AUC: ', 0.82666321696163447)
# ('Training RandomForest with params: ', {'n_estimators': 10, 'min_samples_split': 5})
# ('AUC: ', 0.83530327640698676)
# ('Training RandomForest with params: ', {'n_estimators': 35, 'min_samples_split': 5})
# ('AUC: ', 0.86244558865570609)
# ('Training RandomForest with params: ', {'n_estimators': 1, 'min_samples_split': 10})
# ('AUC: ', 0.79791340823463974)
# ('Training RandomForest with params: ', {'n_estimators': 2, 'min_samples_split': 10})
# ('AUC: ', 0.84488129541467227)
# ('Training RandomForest with params: ', {'n_estimators': 3, 'min_samples_split': 10})
# ('AUC: ', 0.82987279190084373)
# ('Training RandomForest with params: ', {'n_estimators': 10, 'min_samples_split': 10})
# ('AUC: ', 0.88415454954959372)
# ('Training RandomForest with params: ', {'n_estimators': 35, 'min_samples_split': 10})
# ('AUC: ', 0.85924496138099005)
# Best params:
# {'min_samples_split': 10, 'n_estimators': 10}

# %%
preds
# Out:
# array([[ 0.69761326,  0.30238674],
#        [ 0.56600655,  0.43399345],
#        [ 0.16190064,  0.83809936],
#        [ 0.68002562,  0.31997438],
#        [ 0.96079313,  0.03920687],
#        [ 0.68684546,  0.31315454],
#        [ 1.        ,  0.        ],
#        [ 0.48967838,  0.51032162],
#        [ 0.06655329,  0.93344671],
#        [ 0.9515873 ,  0.0484127 ],
#        [ 0.4414237 ,  0.5585763 ],
#        [ 0.52876388,  0.47123612],
#        [ 0.72427668,  0.27572332],
#        [ 0.60316228,  0.39683772],
#        [ 0.06714286,  0.93285714],
#        [ 0.98004535,  0.01995465],
#        [ 0.05281108,  0.94718892],
#        [ 0.71343656,  0.28656344],
#        [ 0.83762421,  0.16237579],
#        [ 0.6001824 ,  0.3998176 ],
#        [ 0.23290043,  0.76709957],
#        [ 0.86625517,  0.13374483],
#        [ 0.73590997,  0.26409003],
#        [ 0.77994077,  0.22005923],
#        [ 0.97321429,  0.02678571],
#        [ 0.99761905,  0.00238095],
#        [ 0.68013641,  0.31986359],
#        [ 0.7541212 ,  0.2458788 ],
#        [ 1.        ,  0.        ],
#        [ 0.62790658,  0.37209342],
#        [ 0.61694647,  0.38305353],
#        [ 0.32137367,  0.67862633],
#        [ 0.83188828,  0.16811172],
#        [ 0.90814884,  0.09185116],
#        [ 0.03525336,  0.96474664],
#        [ 0.81731816,  0.18268184],
#        [ 0.91446797,  0.08553203],
#        [ 0.41680029,  0.58319971],
#        [ 0.14295934,  0.85704066],
#        [ 0.7861703 ,  0.2138297 ],
#        [ 0.75139567,  0.24860433],
#        [ 0.92194805,  0.07805195],
#        [ 0.04428571,  0.95571429],
#        [ 0.74735978,  0.25264022],
#        [ 0.822231  ,  0.177769  ],
#        [ 0.80425801,  0.19574199],
#        [ 0.79547619,  0.20452381],
#        [ 0.48147805,  0.51852195],
#        [ 0.0542735 ,  0.9457265 ],
#        [ 0.16017831,  0.83982169],
#        [ 0.88026164,  0.11973836],
#        [ 0.32516293,  0.67483707],
#        [ 0.97252747,  0.02747253],
#        [ 0.10796283,  0.89203717],
#        [ 0.82228557,  0.17771443],
#        [ 0.9343284 ,  0.0656716 ],
#        [ 0.65239606,  0.34760394],
#        [ 0.97895158,  0.02104842],
#        [ 0.69761326,  0.30238674],
#        [ 0.761654  ,  0.238346  ],
#        [ 0.93822836,  0.06177164],
#        [ 1.        ,  0.        ],
#        [ 0.92736375,  0.07263625],
#        [ 0.02857143,  0.97142857],
#        [ 0.8243736 ,  0.1756264 ],
#        [ 0.89045035,  0.10954965],
#        [ 0.94120047,  0.05879953],
#        [ 0.86639456,  0.13360544],
#        [ 0.6714473 ,  0.3285527 ],
#        [ 0.046976  ,  0.953024  ],
#        [ 0.68594961,  0.31405039],
#        [ 0.74814697,  0.25185303],
#        [ 0.92083333,  0.07916667],
#        [ 0.00714286,  0.99285714],
#        [ 0.93495481,  0.06504519],
#        [ 0.13786432,  0.86213568],
#        [ 0.21411097,  0.78588903],
#        [ 0.02583131,  0.97416869],
#        [ 0.01604278,  0.98395722],
#        [ 0.9715873 ,  0.0284127 ],
#        [ 0.05846764,  0.94153236],
#        [ 0.69643628,  0.30356372],
#        [ 0.39794274,  0.60205726],
#        [ 1.        ,  0.        ],
#        [ 0.14352869,  0.85647131],
#        [ 0.37382751,  0.62617249],
#        [ 0.94965693,  0.05034307],
#        [ 0.51672185,  0.48327815],
#        [ 0.05846764,  0.94153236],
#        [ 0.82967736,  0.17032264],
#        [ 0.72427668,  0.27572332],
#        [ 0.89671202,  0.10328798],
#        [ 0.05725624,  0.94274376],
#        [ 0.6377315 ,  0.3622685 ],
#        [ 0.91126072,  0.08873928],
#        [ 0.9724667 ,  0.0275333 ],
#        [ 0.94937075,  0.05062925],
#        [ 0.8799093 ,  0.1200907 ],
#        [ 0.0377551 ,  0.9622449 ],
#        [ 1.        ,  0.        ],
#        [ 0.85936889,  0.14063111],
#        [ 0.94221389,  0.05778611],
#        [ 0.92736375,  0.07263625],
#        [ 0.0671408 ,  0.9328592 ],
#        [ 0.79871525,  0.20128475],
#        [ 0.67222635,  0.32777365],
#        [ 0.8331307 ,  0.1668693 ],
#        [ 0.83145692,  0.16854308],
#        [ 0.90129252,  0.09870748],
#        [ 0.9461659 ,  0.0538341 ],
#        [ 0.9672286 ,  0.0327714 ],
#        [ 0.84738233,  0.15261767],
#        [ 0.51983756,  0.48016244],
#        [ 0.93441884,  0.06558116],
#        [ 0.27863513,  0.72136487],
#        [ 0.57622665,  0.42377335],
#        [ 0.99285714,  0.00714286],
#        [ 0.9724667 ,  0.0275333 ],
#        [ 0.89062509,  0.10937491],
#        [ 0.14900179,  0.85099821],
#        [ 0.97895158,  0.02104842],
#        [ 0.74735978,  0.25264022],
#        [ 0.02857143,  0.97142857],
#        [ 0.65822765,  0.34177235],
#        [ 0.96458791,  0.03541209],
#        [ 0.74283774,  0.25716226],
#        [ 0.82289699,  0.17710301],
#        [ 0.80425801,  0.19574199],
#        [ 0.04785881,  0.95214119],
#        [ 0.26527179,  0.73472821],
#        [ 0.2180644 ,  0.7819356 ],
#        [ 0.84939659,  0.15060341],
#        [ 0.        ,  1.        ],
#        [ 0.99047619,  0.00952381],
#        [ 0.03121095,  0.96878905],
#        [ 0.85879094,  0.14120906],
#        [ 0.90014069,  0.09985931],
#        [ 0.63480608,  0.36519392],
#        [ 0.73003663,  0.26996337],
#        [ 0.23502521,  0.76497479],
#        [ 0.89791596,  0.10208404],
#        [ 0.56905412,  0.43094588],
#        [ 0.90183194,  0.09816806],
#        [ 0.7861703 ,  0.2138297 ],
#        [ 0.20593971,  0.79406029],
#        [ 0.80772755,  0.19227245],
#        [ 0.98470418,  0.01529582],
#        [ 0.15038549,  0.84961451],
#        [ 0.9515873 ,  0.0484127 ],
#        [ 0.89431416,  0.10568584],
#        [ 1.        ,  0.        ],
#        [ 0.73590997,  0.26409003],
#        [ 0.90167023,  0.09832977],
#        [ 0.9672286 ,  0.0327714 ],
#        [ 0.87788022,  0.12211978],
#        [ 0.36739894,  0.63260106],
#        [ 0.03428571,  0.96571429],
#        [ 1.        ,  0.        ],
#        [ 0.97321429,  0.02678571],
#        [ 0.91798535,  0.08201465],
#        [ 0.9026142 ,  0.0973858 ],
#        [ 0.97252747,  0.02747253],
#        [ 0.70462363,  0.29537637],
#        [ 0.76763857,  0.23236143],
#        [ 1.        ,  0.        ],
#        [ 0.85919913,  0.14080087],
#        [ 0.80103325,  0.19896675],
#        [ 0.00979592,  0.99020408],
#        [ 0.98470418,  0.01529582],
#        [ 0.97892465,  0.02107535],
#        [ 0.11741037,  0.88258963],
#        [ 0.94965693,  0.05034307],
#        [ 0.80595814,  0.19404186],
#        [ 0.94604308,  0.05395692],
#        [ 0.6129549 ,  0.3870451 ],
#        [ 0.7058413 ,  0.2941587 ],
#        [ 0.05226757,  0.94773243],
#        [ 0.83677617,  0.16322383],
#        [ 0.0329262 ,  0.9670738 ],
#        [ 0.26527179,  0.73472821],
#        [ 0.86318066,  0.13681934],
#        [ 0.64446462,  0.35553538],
#        [ 1.        ,  0.        ],
#        [ 1.        ,  0.        ],
#        [ 0.52777056,  0.47222944],
#        [ 0.98348794,  0.01651206],
#        [ 0.9046712 ,  0.0953288 ],
#        [ 0.36860084,  0.63139916],
#        [ 0.9672286 ,  0.0327714 ],
#        [ 0.96960956,  0.03039044],
#        [ 0.08120181,  0.91879819],
#        [ 0.07285714,  0.92714286],
#        [ 0.81172149,  0.18827851],
#        [ 0.56225259,  0.43774741],
#        [ 0.59707764,  0.40292236],
#        [ 0.94657946,  0.05342054],
#        [ 0.81295299,  0.18704701],
#        [ 0.73139813,  0.26860187],
#        [ 0.96785714,  0.03214286],
#        [ 0.73215408,  0.26784592],
#        [ 0.74343083,  0.25656917],
#        [ 0.52466456,  0.47533544],
#        [ 0.16017831,  0.83982169],
#        [ 0.35769548,  0.64230452],
#        [ 0.9672286 ,  0.0327714 ],
#        [ 0.05286951,  0.94713049],
#        [ 0.96369048,  0.03630952],
#        [ 0.70681831,  0.29318169],
#        [ 0.99761905,  0.00238095],
#        [ 0.62360409,  0.37639591],
#        [ 0.15147362,  0.84852638],
#        [ 0.86552154,  0.13447846],
#        [ 0.50760488,  0.49239512],
#        [ 0.85879094,  0.14120906],
#        [ 0.93970522,  0.06029478],
#        [ 0.04520234,  0.95479766],
#        [ 0.75080793,  0.24919207],
#        [ 0.87437206,  0.12562794],
#        [ 0.05514652,  0.94485348],
#        [ 1.        ,  0.        ],
#        [ 0.81172149,  0.18827851],
#        [ 0.88585498,  0.11414502]])

# %% [markdown]
# ## Тюнинг моделей. Способ 2
# Используем GridSearchCV cо своим KFold

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, make_scorer

# функция, скор которой будет выводиться в гридсёче
roc_scorer = make_scorer(lambda y_true, y_pred: roc_auc_score(y_true, y_pred[:, 1]), needs_proba=True)
kf = KFold(n_splits=4, shuffle=True)
gs = GridSearchCV(clf, param_grid=params_grid, verbose=5, scoring=roc_scorer, cv=kf)
# запуск гридсёча
gs.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 15 candidates, totalling 60 fits
# [CV] min_samples_split=2, n_estimators=1 .............................
# [CV]  min_samples_split=2, n_estimators=1, score=0.7697357203751066, total=   0.0s
# [CV] min_samples_split=2, n_estimators=1 .............................
# [CV]  min_samples_split=2, n_estimators=1, score=0.7197008113590264, total=   0.0s
# [CV] min_samples_split=2, n_estimators=1 .............................
# [CV]  min_samples_split=2, n_estimators=1, score=0.7786128691983122, total=   0.0s
# [CV] min_samples_split=2, n_estimators=1 .............................
# [CV]  min_samples_split=2, n_estimators=1, score=0.722045130442077, total=   0.0s
# [CV] min_samples_split=2, n_estimators=2 .............................
# [CV]  min_samples_split=2, n_estimators=2, score=0.8180306905370844, total=   0.0s
# [CV] min_samples_split=2, n_estimators=2 .............................
# [CV]  min_samples_split=2, n_estimators=2, score=0.8078938471940499, total=   0.0s
# [CV] min_samples_split=2, n_estimators=2 .............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [CV]  min_samples_split=2, n_estimators=2, score=0.7964135021097046, total=   0.0s
# [CV] min_samples_split=2, n_estimators=2 .............................
# [CV]  min_samples_split=2, n_estimators=2, score=0.7425132119788609, total=   0.0s
# [CV] min_samples_split=2, n_estimators=3 .............................
# [CV]  min_samples_split=2, n_estimators=3, score=0.8308184143222507, total=   0.0s
# [CV] min_samples_split=2, n_estimators=3 .............................
# [CV]  min_samples_split=2, n_estimators=3, score=0.8671399594320488, total=   0.0s
# [CV] min_samples_split=2, n_estimators=3 .............................
# [CV]  min_samples_split=2, n_estimators=3, score=0.8140822784810127, total=   0.0s
# [CV] min_samples_split=2, n_estimators=3 .............................
# [CV]  min_samples_split=2, n_estimators=3, score=0.7747672175153091, total=   0.0s
# [CV] min_samples_split=2, n_estimators=10 ............................
# [CV]  min_samples_split=2, n_estimators=10, score=0.8466325660699061, total=   0.0s
# [CV] min_samples_split=2, n_estimators=10 ............................
# [CV]  min_samples_split=2, n_estimators=10, score=0.8851419878296145, total=   0.0s
# [CV] min_samples_split=2, n_estimators=10 ............................
# [CV]  min_samples_split=2, n_estimators=10, score=0.8326300984528833, total=   0.0s
# [CV] min_samples_split=2, n_estimators=10 ............................
# [CV]  min_samples_split=2, n_estimators=10, score=0.8143612113077762, total=   0.0s
# [CV] min_samples_split=2, n_estimators=35 ............................
# [CV]  min_samples_split=2, n_estimators=35, score=0.8657715260017051, total=   0.1s
# [CV] min_samples_split=2, n_estimators=35 ............................
# [CV]  min_samples_split=2, n_estimators=35, score=0.8788877620013524, total=   0.1s
# [CV] min_samples_split=2, n_estimators=35 ............................
# [CV]  min_samples_split=2, n_estimators=35, score=0.8519690576652602, total=   0.1s
# [CV] min_samples_split=2, n_estimators=35 ............................
# [CV]  min_samples_split=2, n_estimators=35, score=0.8338646086737689, total=   0.1s
# [CV] min_samples_split=5, n_estimators=1 .............................
# [CV]  min_samples_split=5, n_estimators=1, score=0.7273657289002557, total=   0.0s
# [CV] min_samples_split=5, n_estimators=1 .............................
# [CV]  min_samples_split=5, n_estimators=1, score=0.7723546315077755, total=   0.0s
# [CV] min_samples_split=5, n_estimators=1 .............................
# [CV]  min_samples_split=5, n_estimators=1, score=0.7763713080168776, total=   0.0s
# [CV] min_samples_split=5, n_estimators=1 .............................
# [CV]  min_samples_split=5, n_estimators=1, score=0.7780387551379918, total=   0.0s
# [CV] min_samples_split=5, n_estimators=2 .............................
# [CV]  min_samples_split=5, n_estimators=2, score=0.8010656436487638, total=   0.0s
# [CV] min_samples_split=5, n_estimators=2 .............................
# [CV]  min_samples_split=5, n_estimators=2, score=0.8221771467207573, total=   0.0s
# [CV] min_samples_split=5, n_estimators=2 .............................
# [CV]  min_samples_split=5, n_estimators=2, score=0.8047204641350212, total=   0.0s
# [CV] min_samples_split=5, n_estimators=2 .............................
# [CV]  min_samples_split=5, n_estimators=2, score=0.8090344769734082, total=   0.0s
# [CV] min_samples_split=5, n_estimators=3 .............................
# [CV]  min_samples_split=5, n_estimators=3, score=0.8377664109121908, total=   0.0s
# [CV] min_samples_split=5, n_estimators=3 .............................
# [CV]  min_samples_split=5, n_estimators=3, score=0.8223039215686275, total=   0.0s
# [CV] min_samples_split=5, n_estimators=3 .............................
# [CV]  min_samples_split=5, n_estimators=3, score=0.8258614627285513, total=   0.0s
# [CV] min_samples_split=5, n_estimators=3 .............................
# [CV]  min_samples_split=5, n_estimators=3, score=0.806014596090932, total=   0.0s
# [CV] min_samples_split=5, n_estimators=10 ............................
# [CV]  min_samples_split=5, n_estimators=10, score=0.8796248934356351, total=   0.0s
# [CV] min_samples_split=5, n_estimators=10 ............................
# [CV]  min_samples_split=5, n_estimators=10, score=0.8656186612576064, total=   0.0s
# [CV] min_samples_split=5, n_estimators=10 ............................
# [CV]  min_samples_split=5, n_estimators=10, score=0.8502988748241913, total=   0.0s
# [CV] min_samples_split=5, n_estimators=10 ............................
# [CV]  min_samples_split=5, n_estimators=10, score=0.8422112238906132, total=   0.0s
# [CV] min_samples_split=5, n_estimators=35 ............................
# [CV]  min_samples_split=5, n_estimators=35, score=0.8828644501278773, total=   0.2s
# [CV] min_samples_split=5, n_estimators=35 ............................
# [CV]  min_samples_split=5, n_estimators=35, score=0.8886916835699797, total=   0.3s
# [CV] min_samples_split=5, n_estimators=35 ............................
# [CV]  min_samples_split=5, n_estimators=35, score=0.8437939521800282, total=   0.2s
# [CV] min_samples_split=5, n_estimators=35 ............................
# [CV]  min_samples_split=5, n_estimators=35, score=0.849005955876185, total=   0.2s
# [CV] min_samples_split=10, n_estimators=1 ............................
# [CV]  min_samples_split=10, n_estimators=1, score=0.8081841432225063, total=   0.0s
# [CV] min_samples_split=10, n_estimators=1 ............................
# [CV]  min_samples_split=10, n_estimators=1, score=0.7709601081812034, total=   0.0s
# [CV] min_samples_split=10, n_estimators=1 ............................
# [CV]  min_samples_split=10, n_estimators=1, score=0.8065225035161745, total=   0.0s
# [CV] min_samples_split=10, n_estimators=1 ............................
# [CV]  min_samples_split=10, n_estimators=1, score=0.7683499706400471, total=   0.0s
# [CV] min_samples_split=10, n_estimators=2 ............................
# [CV]  min_samples_split=10, n_estimators=2, score=0.8378516624040921, total=   0.0s
# [CV] min_samples_split=10, n_estimators=2 ............................
# [CV]  min_samples_split=10, n_estimators=2, score=0.8589418526031102, total=   0.0s
# [CV] min_samples_split=10, n_estimators=2 ............................
# [CV]  min_samples_split=10, n_estimators=2, score=0.8132911392405062, total=   0.0s
# [CV] min_samples_split=10, n_estimators=2 ............................
# [CV]  min_samples_split=10, n_estimators=2, score=0.8381427732572772, total=   0.0s
# [CV] min_samples_split=10, n_estimators=3 ............................
# [CV]  min_samples_split=10, n_estimators=3, score=0.8593350383631714, total=   0.0s
# [CV] min_samples_split=10, n_estimators=3 ............................
# [CV]  min_samples_split=10, n_estimators=3, score=0.8839587559161595, total=   0.0s
# [CV] min_samples_split=10, n_estimators=3 ............................
# [CV]  min_samples_split=10, n_estimators=3, score=0.8126758087201125, total=   0.0s
# [CV] min_samples_split=10, n_estimators=3 ............................
# [CV]  min_samples_split=10, n_estimators=3, score=0.8194362889019378, total=   0.0s
# [CV] min_samples_split=10, n_estimators=10 ...........................
# [CV]  min_samples_split=10, n_estimators=10, score=0.876385336743393, total=   0.0s
# [CV] min_samples_split=10, n_estimators=10 ...........................
# [CV]  min_samples_split=10, n_estimators=10, score=0.879817444219067, total=   0.0s
# [CV] min_samples_split=10, n_estimators=10 ...........................
# [CV]  min_samples_split=10, n_estimators=10, score=0.8408052039381154, total=   0.0s
# [CV] min_samples_split=10, n_estimators=10 ...........................
# [CV]  min_samples_split=10, n_estimators=10, score=0.8486284707658753, total=   0.0s
# [CV] min_samples_split=10, n_estimators=35 ...........................
# [CV]  min_samples_split=10, n_estimators=35, score=0.8822676896845696, total=   0.2s
# [CV] min_samples_split=10, n_estimators=35 ...........................
# [CV]  min_samples_split=10, n_estimators=35, score=0.8839164976335361, total=   0.1s
# [CV] min_samples_split=10, n_estimators=35 ...........................
# [CV]  min_samples_split=10, n_estimators=35, score=0.8425632911392404, total=   0.2s
# [CV] min_samples_split=10, n_estimators=35 ...........................
# [CV]  min_samples_split=10, n_estimators=35, score=0.8628470765875347, total=   0.3s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:    5.8s finished
# GridSearchCV(cv=KFold(n_splits=4, random_state=None, shuffle=True),
#        error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=35, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': [1, 2, 3, 10, 35], 'min_samples_split': [2, 5, 10]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=make_scorer(<lambda>, needs_proba=True), verbose=5)

# %%
gs.best_score_, gs.best_params_
# Out:
# (0.86790430830350263, {'min_samples_split': 10, 'n_estimators': 35})

# %%
gs.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=35, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# ## Тюнинг моделей. Способ 3
# Ипользуем GridSearchCV со встроенным KFold и встроенной метрикой качества

# %%
gs = GridSearchCV(clf, param_grid=params_grid, verbose=5, cv=4)
gs.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 15 candidates, totalling 60 fits
# [CV] min_samples_split=2, n_estimators=1 .............................
# [CV]  min_samples_split=2, n_estimators=1, score=0.7455357142857143, total=   0.0s
# [CV] min_samples_split=2, n_estimators=1 .............................
# [CV]  min_samples_split=2, n_estimators=1, score=0.8116591928251121, total=   0.0s
# [CV] min_samples_split=2, n_estimators=1 .............................
# [CV]  min_samples_split=2, n_estimators=1, score=0.7612612612612613, total=   0.0s
# [CV] min_samples_split=2, n_estimators=1 .............................
# [CV]  min_samples_split=2, n_estimators=1, score=0.8063063063063063, total=   0.0s
# [CV] min_samples_split=2, n_estimators=2 .............................
# [CV]  min_samples_split=2, n_estimators=2, score=0.7455357142857143, total=   0.0s
# [CV] min_samples_split=2, n_estimators=2 .............................
# [CV]  min_samples_split=2, n_estimators=2, score=0.7937219730941704, total=   0.0s
# [CV] min_samples_split=2, n_estimators=2 .............................
# [CV]  min_samples_split=2, n_estimators=2, score=0.7477477477477478, total=   0.0s
# [CV] min_samples_split=2, n_estimators=2 .............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [CV]  min_samples_split=2, n_estimators=2, score=0.7927927927927928, total=   0.0s
# [CV] min_samples_split=2, n_estimators=3 .............................
# [CV]  min_samples_split=2, n_estimators=3, score=0.7276785714285714, total=   0.0s
# [CV] min_samples_split=2, n_estimators=3 .............................
# [CV]  min_samples_split=2, n_estimators=3, score=0.8026905829596412, total=   0.0s
# [CV] min_samples_split=2, n_estimators=3 .............................
# [CV]  min_samples_split=2, n_estimators=3, score=0.7657657657657657, total=   0.0s
# [CV] min_samples_split=2, n_estimators=3 .............................
# [CV]  min_samples_split=2, n_estimators=3, score=0.7972972972972973, total=   0.0s
# [CV] min_samples_split=2, n_estimators=10 ............................
# [CV]  min_samples_split=2, n_estimators=10, score=0.7633928571428571, total=   0.0s
# [CV] min_samples_split=2, n_estimators=10 ............................
# [CV]  min_samples_split=2, n_estimators=10, score=0.7982062780269058, total=   0.0s
# [CV] min_samples_split=2, n_estimators=10 ............................
# [CV]  min_samples_split=2, n_estimators=10, score=0.7792792792792793, total=   0.0s
# [CV] min_samples_split=2, n_estimators=10 ............................
# [CV]  min_samples_split=2, n_estimators=10, score=0.8108108108108109, total=   0.0s
# [CV] min_samples_split=2, n_estimators=35 ............................
# [CV]  min_samples_split=2, n_estimators=35, score=0.7544642857142857, total=   0.1s
# [CV] min_samples_split=2, n_estimators=35 ............................
# [CV]  min_samples_split=2, n_estimators=35, score=0.8475336322869955, total=   0.1s
# [CV] min_samples_split=2, n_estimators=35 ............................
# [CV]  min_samples_split=2, n_estimators=35, score=0.8108108108108109, total=   0.1s
# [CV] min_samples_split=2, n_estimators=35 ............................
# [CV]  min_samples_split=2, n_estimators=35, score=0.7882882882882883, total=   0.1s
# [CV] min_samples_split=5, n_estimators=1 .............................
# [CV]  min_samples_split=5, n_estimators=1, score=0.7946428571428571, total=   0.0s
# [CV] min_samples_split=5, n_estimators=1 .............................
# [CV]  min_samples_split=5, n_estimators=1, score=0.8295964125560538, total=   0.0s
# [CV] min_samples_split=5, n_estimators=1 .............................
# [CV]  min_samples_split=5, n_estimators=1, score=0.7567567567567568, total=   0.0s
# [CV] min_samples_split=5, n_estimators=1 .............................
# [CV]  min_samples_split=5, n_estimators=1, score=0.7702702702702703, total=   0.0s
# [CV] min_samples_split=5, n_estimators=2 .............................
# [CV]  min_samples_split=5, n_estimators=2, score=0.7321428571428571, total=   0.0s
# [CV] min_samples_split=5, n_estimators=2 .............................
# [CV]  min_samples_split=5, n_estimators=2, score=0.7937219730941704, total=   0.0s
# [CV] min_samples_split=5, n_estimators=2 .............................
# [CV]  min_samples_split=5, n_estimators=2, score=0.8018018018018018, total=   0.0s
# [CV] min_samples_split=5, n_estimators=2 .............................
# [CV]  min_samples_split=5, n_estimators=2, score=0.7612612612612613, total=   0.0s
# [CV] min_samples_split=5, n_estimators=3 .............................
# [CV]  min_samples_split=5, n_estimators=3, score=0.7366071428571429, total=   0.0s
# [CV] min_samples_split=5, n_estimators=3 .............................
# [CV]  min_samples_split=5, n_estimators=3, score=0.8295964125560538, total=   0.0s
# [CV] min_samples_split=5, n_estimators=3 .............................
# [CV]  min_samples_split=5, n_estimators=3, score=0.7702702702702703, total=   0.0s
# [CV] min_samples_split=5, n_estimators=3 .............................
# [CV]  min_samples_split=5, n_estimators=3, score=0.7747747747747747, total=   0.0s
# [CV] min_samples_split=5, n_estimators=10 ............................
# [CV]  min_samples_split=5, n_estimators=10, score=0.7678571428571429, total=   0.0s
# [CV] min_samples_split=5, n_estimators=10 ............................
# [CV]  min_samples_split=5, n_estimators=10, score=0.8295964125560538, total=   0.0s
# [CV] min_samples_split=5, n_estimators=10 ............................
# [CV]  min_samples_split=5, n_estimators=10, score=0.8288288288288288, total=   0.0s
# [CV] min_samples_split=5, n_estimators=10 ............................
# [CV]  min_samples_split=5, n_estimators=10, score=0.8153153153153153, total=   0.0s
# [CV] min_samples_split=5, n_estimators=35 ............................
# [CV]  min_samples_split=5, n_estimators=35, score=0.7946428571428571, total=   0.2s
# [CV] min_samples_split=5, n_estimators=35 ............................
# [CV]  min_samples_split=5, n_estimators=35, score=0.8565022421524664, total=   0.2s
# [CV] min_samples_split=5, n_estimators=35 ............................
# [CV]  min_samples_split=5, n_estimators=35, score=0.8378378378378378, total=   0.1s
# [CV] min_samples_split=5, n_estimators=35 ............................
# [CV]  min_samples_split=5, n_estimators=35, score=0.8423423423423423, total=   0.2s
# [CV] min_samples_split=10, n_estimators=1 ............................
# [CV]  min_samples_split=10, n_estimators=1, score=0.7589285714285714, total=   0.0s
# [CV] min_samples_split=10, n_estimators=1 ............................
# [CV]  min_samples_split=10, n_estimators=1, score=0.8116591928251121, total=   0.0s
# [CV] min_samples_split=10, n_estimators=1 ............................
# [CV]  min_samples_split=10, n_estimators=1, score=0.7882882882882883, total=   0.0s
# [CV] min_samples_split=10, n_estimators=1 ............................
# [CV]  min_samples_split=10, n_estimators=1, score=0.7837837837837838, total=   0.0s
# [CV] min_samples_split=10, n_estimators=2 ............................
# [CV]  min_samples_split=10, n_estimators=2, score=0.7633928571428571, total=   0.0s
# [CV] min_samples_split=10, n_estimators=2 ............................
# [CV]  min_samples_split=10, n_estimators=2, score=0.8161434977578476, total=   0.0s
# [CV] min_samples_split=10, n_estimators=2 ............................
# [CV]  min_samples_split=10, n_estimators=2, score=0.7927927927927928, total=   0.0s
# [CV] min_samples_split=10, n_estimators=2 ............................
# [CV]  min_samples_split=10, n_estimators=2, score=0.8198198198198198, total=   0.0s
# [CV] min_samples_split=10, n_estimators=3 ............................
# [CV]  min_samples_split=10, n_estimators=3, score=0.7455357142857143, total=   0.0s
# [CV] min_samples_split=10, n_estimators=3 ............................
# [CV]  min_samples_split=10, n_estimators=3, score=0.8475336322869955, total=   0.0s
# [CV] min_samples_split=10, n_estimators=3 ............................
# [CV]  min_samples_split=10, n_estimators=3, score=0.8018018018018018, total=   0.0s
# [CV] min_samples_split=10, n_estimators=3 ............................
# [CV]  min_samples_split=10, n_estimators=3, score=0.8378378378378378, total=   0.0s
# [CV] min_samples_split=10, n_estimators=10 ...........................
# [CV]  min_samples_split=10, n_estimators=10, score=0.7991071428571429, total=   0.0s
# [CV] min_samples_split=10, n_estimators=10 ...........................
# [CV]  min_samples_split=10, n_estimators=10, score=0.852017937219731, total=   0.0s
# [CV] min_samples_split=10, n_estimators=10 ...........................
# [CV]  min_samples_split=10, n_estimators=10, score=0.8198198198198198, total=   0.0s
# [CV] min_samples_split=10, n_estimators=10 ...........................
# [CV]  min_samples_split=10, n_estimators=10, score=0.8513513513513513, total=   0.0s
# [CV] min_samples_split=10, n_estimators=35 ...........................
# [CV]  min_samples_split=10, n_estimators=35, score=0.78125, total=   0.2s
# [CV] min_samples_split=10, n_estimators=35 ...........................
# [CV]  min_samples_split=10, n_estimators=35, score=0.8654708520179372, total=   0.2s
# [CV] min_samples_split=10, n_estimators=35 ...........................
# [CV]  min_samples_split=10, n_estimators=35, score=0.8243243243243243, total=   0.2s
# [CV] min_samples_split=10, n_estimators=35 ...........................
# [CV]  min_samples_split=10, n_estimators=35, score=0.8378378378378378, total=   0.2s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:    5.6s finished
# GridSearchCV(cv=4, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=35, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': [1, 2, 3, 10, 35], 'min_samples_split': [2, 5, 10]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=5)

# %% [markdown]
# ## Тюнинг моделей. Способ 4
# Используя OOB-score (работает только для НЕбустинговых ансамблей)

# %%
from sklearn.metrics import roc_auc_score

kf = KFold(n_splits=4, shuffle=True) # Всегда делайте shuffle если обучаете не на последовательных данных!

best_score = 0
best_params = {}

# Опять создадим всевозможные комбинации параметров модели
params = [{}]
for parameter_name in params_grid:
    parameter_values = params_grid[parameter_name]
    new_params = []
    for value in parameter_values:    
        for param in params:
            updated_param = param.copy()
            updated_param[parameter_name] = value
            new_params.append(updated_param)
    params = new_params
    
for param in params:
    print(('Training RandomForest with params: ', param))
    clf.set_params(**param)
    clf.set_params(oob_score=True)
    
    # Это то, что нам требовалось делать раньше
#     fold_aucs = []
#     for train_idx, test_idx in kf.split(X_train):
#         X_train_fold, X_test_fold = X_train.iloc[train_idx], X_train.iloc[test_idx]
#         y_train_fold, y_test_fold = y_train.iloc[train_idx], y_train.iloc[test_idx]
#         clf.fit(X_train_fold, y_train_fold)
#         preds = clf.predict_proba(X_test_fold)
#         auc = roc_auc_score(y_test_fold, preds[:, 1])
#         fold_aucs.append(auc)
#     print(('AUC: ', np.mean(fold_aucs)))

    # А это то, что мы можем делать сейчас без всех махинаций с KFold'ом выше
    clf.fit(X_train, y_train)
    oob_score = clf.oob_score_
    
    print(('OOB: ', oob_score))
    if oob_score > best_score:
        best_score = oob_score
        best_params = param

print('Best params:')
best_params
# Out:
# ('Training RandomForest with params: ', {'n_estimators': 1, 'min_samples_split': 2})
# ('OOB: ', 0.68125701459034793)
# ('Training RandomForest with params: ', {'n_estimators': 2, 'min_samples_split': 2})
# ('OOB: ', 0.71380471380471378)
# ('Training RandomForest with params: ', {'n_estimators': 3, 'min_samples_split': 2})
# ('OOB: ', 0.74186307519640848)
# ('Training RandomForest with params: ', {'n_estimators': 10, 'min_samples_split': 2})
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:451: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:456: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:451: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:456: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:451: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:456: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:451: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:456: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# ('OOB: ', 0.79349046015712688)
# ('Training RandomForest with params: ', {'n_estimators': 35, 'min_samples_split': 2})
# ('OOB: ', 0.8125701459034792)
# ('Training RandomForest with params: ', {'n_estimators': 1, 'min_samples_split': 5})
# ('OOB: ', 0.67901234567901236)
# ('Training RandomForest with params: ', {'n_estimators': 2, 'min_samples_split': 5})
# ('OOB: ', 0.72278338945005616)
# ('Training RandomForest with params: ', {'n_estimators': 3, 'min_samples_split': 5})
# ('OOB: ', 0.72053872053872059)
# ('Training RandomForest with params: ', {'n_estimators': 10, 'min_samples_split': 5})
# ('OOB: ', 0.80134680134680136)
# ('Training RandomForest with params: ', {'n_estimators': 35, 'min_samples_split': 5})
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:451: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:456: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:451: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:456: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:451: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:456: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:451: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:456: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# ('OOB: ', 0.82154882154882158)
# ('Training RandomForest with params: ', {'n_estimators': 1, 'min_samples_split': 10})
# ('OOB: ', 0.66778900112233441)
# ('Training RandomForest with params: ', {'n_estimators': 2, 'min_samples_split': 10})
# ('OOB: ', 0.72278338945005616)
# ('Training RandomForest with params: ', {'n_estimators': 3, 'min_samples_split': 10})
# ('OOB: ', 0.755331088664422)
# ('Training RandomForest with params: ', {'n_estimators': 10, 'min_samples_split': 10})
# ('OOB: ', 0.80808080808080807)
# ('Training RandomForest with params: ', {'n_estimators': 35, 'min_samples_split': 10})
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:451: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:456: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:451: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:456: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:451: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:456: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:451: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:456: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# ('OOB: ', 0.83613916947250277)
# Best params:
# {'min_samples_split': 10, 'n_estimators': 35}

# %% [markdown]
# ## Практическое задание 1
# Используя понравившийся метод, попробуйте подобрать самые важные на ваш взгляд параметры для RandomForestClassifier и GradientBoostingClassifier

# %% [markdown]
# ## Предсказание моделей для стеккинга

# %% [markdown]
# ## Предсказание моделей для стекинга. Способ 1
# "В лоб"

# %%
X_train.shape
# Out:
# (891, 9)

# %%
y_train.shape
# Out:
# (891,)

# %%
from sklearn.ensemble import GradientBoostingClassifier 

def cross_val_predict_proba(estimator, X_train, y_train):
    kfold = KFold(n_splits=4, shuffle=True, random_state=None)
    estimator_scores = np.zeros_like(y_train)
    for train_idx, test_idx in kfold.split(X_train):
        X_train_fold, X_pred_fold = X_train.iloc[train_idx], X_train.iloc[test_idx]
        y_train_fold, _ = y_train.iloc[train_idx], y_train.iloc[test_idx]
        estimator.fit(X_train_fold, y_train_fold)
        estimator_scores[test_idx] = estimator.predict_proba(X_test_fold)[:, 1]
    return estimator_scores
#     return cross_val_predict(estimator, X_train, y_train, cv=kfold, method='predict_proba')

# инициализирем модели с подобранными гиперпараметрами
rf_estimator = RandomForestClassifier()
gb_estimator = GradientBoostingClassifier()

# получаем предсказания вероятностей ансамблей на кросс-валидации для обучающей выборки
rf_train_pred = cross_val_predict_proba(rf_estimator, X_train, y_train)
gb_train_pred = cross_val_predict_proba(gb_estimator, X_train, y_train)

X_train_stack = np.stack([rf_train_pred, gb_train_pred], axis=1)

# получаем предсказания ансамблей для тестовой выборки
rf_test_pred = rf_estimator.fit(X_train, y_train).predict_proba(X_test)
gb_test_pred = gb_estimator.fit(X_train, y_train).predict_proba(X_test)

X_test_stack = np.stack([rf_test_pred[:,1], gb_test_pred[:,1]], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-49b225d56022> in <module>()
#      17
#      18 # получаем предсказания вероятностей ансамблей на кросс-валидации для обучающей выборки
# ---> 19 rf_train_pred = cross_val_predict_proba(rf_estimator, X_train, y_train)
#      20 gb_train_pred = cross_val_predict_proba(gb_estimator, X_train, y_train)
#      21
#
# <ipython-input-22-49b225d56022> in cross_val_predict_proba(estimator, X_train, y_train)
#       8         y_train_fold, _ = y_train.iloc[train_idx], y_train.iloc[test_idx]
#       9         estimator.fit(X_train_fold, y_train_fold)
# ---> 10         estimator_scores[test_idx] = estimator.predict_proba(X_test_fold)[:, 1]
#      11     return estimator_scores
#      12 #     return cross_val_predict(estimator, X_train, y_train, cv=kfold, method='predict_proba')
#
# ValueError: shape mismatch: value array of shape (222,) could not be broadcast to indexing result of shape (223,)

# %%
X_test_stack
# Out:
# array([[ 0.        ,  0.04635935],
#        [ 0.1       ,  0.12779691],
#        [ 0.        ,  0.13986669],
#        [ 0.7       ,  0.14068034],
#        [ 0.3       ,  0.4036792 ],
#        [ 0.1       ,  0.11170511],
#        [ 0.3       ,  0.24903108],
#        [ 0.        ,  0.28030803],
#        [ 0.7       ,  0.90190717],
#        [ 0.        ,  0.08107034],
#        [ 0.        ,  0.09280331],
#        [ 0.        ,  0.07143607],
#        [ 1.        ,  0.933683  ],
#        [ 0.1       ,  0.12858014],
#        [ 1.        ,  0.86025295],
#        [ 1.        ,  0.9270053 ],
#        [ 0.1       ,  0.07317554],
#        [ 0.8       ,  0.16838866],
#        [ 0.4       ,  0.53839304],
#        [ 0.2       ,  0.37241087],
#        [ 0.6       ,  0.28427084],
#        [ 0.5       ,  0.49216374],
#        [ 1.        ,  0.94539501],
#        [ 0.5       ,  0.40325586],
#        [ 0.9       ,  0.93250822],
#        [ 0.        ,  0.04924125],
#        [ 1.        ,  0.95974208],
#        [ 0.7       ,  0.16838866],
#        [ 0.6       ,  0.43061574],
#        [ 0.4       ,  0.17336078],
#        [ 0.        ,  0.05823568],
#        [ 0.        ,  0.1923209 ],
#        [ 0.5       ,  0.50726612],
#        [ 0.1       ,  0.25099956],
#        [ 0.7       ,  0.53977726],
#        [ 0.6       ,  0.16838866],
#        [ 0.        ,  0.33989061],
#        [ 0.2       ,  0.30641091],
#        [ 0.        ,  0.10705655],
#        [ 0.60416667,  0.51538584],
#        [ 0.4       ,  0.07686773],
#        [ 0.69166667,  0.42756762],
#        [ 0.        ,  0.06766657],
#        [ 1.        ,  0.89145109],
#        [ 1.        ,  0.95523579],
#        [ 0.        ,  0.13276729],
#        [ 0.7       ,  0.17678256],
#        [ 0.06197552,  0.143781  ],
#        [ 0.9       ,  0.95422915],
#        [ 0.5       ,  0.59789748],
#        [ 0.6       ,  0.25850309],
#        [ 0.1       ,  0.12899341],
#        [ 0.7       ,  0.86211146],
#        [ 0.9       ,  0.78778111],
#        [ 0.1       ,  0.17316565],
#        [ 0.1       ,  0.09133075],
#        [ 0.        ,  0.07749877],
#        [ 0.        ,  0.11049537],
#        [ 0.        ,  0.11898301],
#        [ 1.        ,  0.9740206 ],
#        [ 0.        ,  0.09222655],
#        [ 0.3       ,  0.15863344],
#        [ 0.        ,  0.09709363],
#        [ 0.7       ,  0.82838183],
#        [ 0.7       ,  0.60823808],
#        [ 0.9       ,  0.90368307],
#        [ 1.        ,  0.74380762],
#        [ 0.1       ,  0.10948046],
#        [ 0.2       ,  0.27698585],
#        [ 0.9       ,  0.89300695],
#        [ 0.7       ,  0.734608  ],
#        [ 0.        ,  0.08830799],
#        [ 0.2       ,  0.48892562],
#        [ 0.        ,  0.40744847],
#        [ 1.        ,  0.9740206 ],
#        [ 0.3       ,  0.38905539],
#        [ 0.        ,  0.1226044 ],
#        [ 0.9       ,  0.93709792],
#        [ 0.        ,  0.11865336],
#        [ 0.7       ,  0.734608  ],
#        [ 0.8       ,  0.92718677],
#        [ 0.7       ,  0.08564878],
#        [ 0.1       ,  0.24997971],
#        [ 0.        ,  0.09280331],
#        [ 0.3       ,  0.14521253],
#        [ 0.1       ,  0.12149639],
#        [ 1.        ,  0.79078179],
#        [ 0.3       ,  0.32539677],
#        [ 0.90738095,  0.74675676],
#        [ 1.        ,  0.93481995],
#        [ 0.4       ,  0.38076489],
#        [ 0.53333333,  0.09769756],
#        [ 1.        ,  0.93138737],
#        [ 0.        ,  0.1226044 ],
#        [ 0.4       ,  0.21418987],
#        [ 0.15      ,  0.09298947],
#        [ 1.        ,  0.8920993 ],
#        [ 0.3       ,  0.14632917],
#        [ 0.6       ,  0.49552482],
#        [ 0.3       ,  0.14389292],
#        [ 1.        ,  0.9678034 ],
#        [ 0.3       ,  0.12652584],
#        [ 0.06197552,  0.143781  ],
#        [ 0.25      ,  0.12280274],
#        [ 0.7       ,  0.56405765],
#        [ 0.        ,  0.13176177],
#        [ 0.1       ,  0.14318713],
#        [ 0.06197552,  0.143781  ],
#        [ 0.1       ,  0.11835055],
#        [ 0.        ,  0.1038616 ],
#        [ 0.        ,  0.05042036],
#        [ 0.94      ,  0.74675676],
#        [ 0.9       ,  0.96727864],
#        [ 0.7       ,  0.87436889],
#        [ 1.        ,  0.96342488],
#        [ 0.4       ,  0.11984795],
#        [ 0.        ,  0.04662927],
#        [ 1.        ,  0.9068569 ],
#        [ 0.5       ,  0.49606288],
#        [ 1.        ,  0.88589999],
#        [ 0.9       ,  0.90914033],
#        [ 0.05      ,  0.14598608],
#        [ 1.        ,  0.96407349],
#        [ 0.05      ,  0.08041879],
#        [ 0.06197552,  0.143781  ],
#        [ 0.5       ,  0.56042575],
#        [ 0.1       ,  0.09298947],
#        [ 0.9       ,  0.69484115],
#        [ 0.50833333,  0.11378152],
#        [ 0.        ,  0.11095555],
#        [ 0.7375    ,  0.18867288],
#        [ 0.3       ,  0.14233578],
#        [ 0.2       ,  0.1213398 ],
#        [ 0.1       ,  0.04742693],
#        [ 0.        ,  0.06425736],
#        [ 0.        ,  0.08830799],
#        [ 0.        ,  0.29378586],
#        [ 0.        ,  0.13110257],
#        [ 0.        ,  0.31500906],
#        [ 0.1       ,  0.08161453],
#        [ 0.2       ,  0.06264714],
#        [ 1.        ,  0.95346884],
#        [ 0.5       ,  0.218996  ],
#        [ 0.11666667,  0.11775131],
#        [ 0.81666667,  0.42331732],
#        [ 0.1       ,  0.25376878],
#        [ 0.06666667,  0.22236284],
#        [ 0.        ,  0.11095555],
#        [ 0.69166667,  0.42756762],
#        [ 0.2       ,  0.11445398],
#        [ 1.        ,  0.96721923],
#        [ 0.0125    ,  0.143781  ],
#        [ 0.1       ,  0.05136264],
#        [ 0.5       ,  0.50017363],
#        [ 0.        ,  0.10345066],
#        [ 0.        ,  0.11049537],
#        [ 0.9       ,  0.94224305],
#        [ 0.4       ,  0.4835994 ],
#        [ 0.81666667,  0.42331732],
#        [ 0.7       ,  0.5036295 ],
#        [ 0.98571429,  0.7597685 ],
#        [ 0.8       ,  0.83891285],
#        [ 0.8       ,  0.90200021],
#        [ 0.2       ,  0.04407746],
#        [ 0.35833333,  0.11378152],
#        [ 0.5       ,  0.51072093],
#        [ 0.7       ,  0.43680829],
#        [ 0.        ,  0.21351988],
#        [ 0.9       ,  0.94273852],
#        [ 0.1       ,  0.39508006],
#        [ 0.125     ,  0.05895964],
#        [ 0.1       ,  0.29378586],
#        [ 0.        ,  0.10056546],
#        [ 0.15297619,  0.11943071],
#        [ 0.        ,  0.18722331],
#        [ 1.        ,  0.93569837],
#        [ 1.        ,  0.93418288],
#        [ 0.5       ,  0.41889695],
#        [ 1.        ,  0.94667032],
#        [ 0.9       ,  0.89660968],
#        [ 0.        ,  0.11865336],
#        [ 0.5       ,  0.46461641],
#        [ 1.        ,  0.93810256],
#        [ 0.06197552,  0.143781  ],
#        [ 0.8       ,  0.9427918 ],
#        [ 0.        ,  0.11595692],
#        [ 1.        ,  0.90220398],
#        [ 0.36      ,  0.09332474],
#        [ 0.        ,  0.06357947],
#        [ 0.025     ,  0.11378152],
#        [ 0.        ,  0.13000345],
#        [ 0.03333333,  0.1561529 ],
#        [ 0.7       ,  0.3335799 ],
#        [ 0.1       ,  0.04264624],
#        [ 0.9       ,  0.76142145],
#        [ 0.3       ,  0.07749877],
#        [ 0.7       ,  0.94841182],
#        [ 0.4       ,  0.50972441],
#        [ 0.        ,  0.09538444],
#        [ 0.        ,  0.53290095],
#        [ 0.4       ,  0.77460833],
#        [ 1.        ,  0.96157086],
#        [ 0.5       ,  0.19400841],
#        [ 0.9       ,  0.93939264],
#        [ 0.        ,  0.09538444],
#        [ 0.3       ,  0.22502971],
#        [ 0.28333333,  0.32277869],
#        [ 0.        ,  0.09538444],
#        [ 0.9       ,  0.9016968 ],
#        [ 0.        ,  0.08830799],
#        [ 0.1       ,  0.20163091],
#        [ 0.        ,  0.04407746],
#        [ 0.1       ,  0.28947982],
#        [ 0.3       ,  0.84695714],
#        [ 0.1       ,  0.61524426],
#        [ 0.2       ,  0.22517728],
#        [ 1.        ,  0.74675676],
#        [ 0.3       ,  0.17852401],
#        [ 0.9       ,  0.94286626],
#        [ 0.        ,  0.1226044 ],
#        [ 1.        ,  0.8304648 ],
#        [ 0.        ,  0.11095555],
#        [ 1.        ,  0.8654484 ],
#        [ 0.7       ,  0.09298947],
#        [ 0.6       ,  0.84636558],
#        [ 0.2       ,  0.61674837],
#        [ 0.        ,  0.09298947],
#        [ 0.90738095,  0.74675676],
#        [ 0.1       ,  0.08995285],
#        [ 0.        ,  0.13468658],
#        [ 0.3       ,  0.31723726],
#        [ 1.        ,  0.92537407],
#        [ 0.2       ,  0.07881553],
#        [ 0.00769231,  0.143781  ],
#        [ 0.7       ,  0.39149902],
#        [ 0.        ,  0.09222655],
#        [ 0.5       ,  0.14688554],
#        [ 0.8       ,  0.16838866],
#        [ 0.7       ,  0.86561107],
#        [ 0.9       ,  0.97685684],
#        [ 0.8       ,  0.83009426],
#        [ 0.9       ,  0.94387961],
#        [ 0.4       ,  0.60670985],
#        [ 0.        ,  0.09280331],
#        [ 0.        ,  0.11898301],
#        [ 0.2       ,  0.21229444],
#        [ 0.8       ,  0.89338678],
#        [ 0.        ,  0.26154193],
#        [ 1.        ,  0.88589999],
#        [ 0.2       ,  0.48779785],
#        [ 0.9       ,  0.92382854],
#        [ 0.        ,  0.13835926],
#        [ 0.5       ,  0.31283186],
#        [ 0.        ,  0.10705655],
#        [ 0.7       ,  0.18260381],
#        [ 0.125     ,  0.05895964],
#        [ 0.06197552,  0.143781  ],
#        [ 0.        ,  0.1226044 ],
#        [ 0.9       ,  0.87608409],
#        [ 0.3       ,  0.09298947],
#        [ 0.2       ,  0.09349528],
#        [ 0.        ,  0.08830799],
#        [ 0.9       ,  0.90368307],
#        [ 0.9       ,  0.87106991],
#        [ 0.4       ,  0.07781196],
#        [ 0.        ,  0.09280331],
#        [ 0.        ,  0.04984001],
#        [ 0.125     ,  0.05895964],
#        [ 0.        ,  0.33989061],
#        [ 0.        ,  0.11170511],
#        [ 0.5       ,  0.25967539],
#        [ 0.06197552,  0.143781  ],
#        [ 1.        ,  0.95071325],
#        [ 0.8       ,  0.7648824 ],
#        [ 0.        ,  0.11943071],
#        [ 1.        ,  0.87913146],
#        [ 0.06666667,  0.1055927 ],
#        [ 0.        ,  0.10452644],
#        [ 0.1       ,  0.11445398],
#        [ 0.06666667,  0.09538444],
#        [ 0.        ,  0.30641091],
#        [ 1.        ,  0.96606185],
#        [ 0.90738095,  0.74675676],
#        [ 0.2       ,  0.61222716],
#        [ 0.7       ,  0.74673841],
#        [ 0.        ,  0.06354079],
#        [ 0.05      ,  0.08041879],
#        [ 0.3       ,  0.29218307],
#        [ 0.15297619,  0.11943071],
#        [ 0.        ,  0.1226044 ],
#        [ 0.1       ,  0.22236284],
#        [ 0.1       ,  0.04643762],
#        [ 0.15297619,  0.11943071],
#        [ 0.2       ,  0.28875737],
#        [ 0.3       ,  0.13901748],
#        [ 0.        ,  0.11681365],
#        [ 1.        ,  0.95282152],
#        [ 0.4       ,  0.17336078],
#        [ 0.        ,  0.23731504],
#        [ 0.        ,  0.09280331],
#        [ 0.2       ,  0.11680812],
#        [ 0.1       ,  0.1035727 ],
#        [ 0.1       ,  0.09116075],
#        [ 0.        ,  0.10705655],
#        [ 0.90738095,  0.74675676],
#        [ 1.        ,  0.82460354],
#        [ 0.7       ,  0.21234428],
#        [ 0.8       ,  0.88979569],
#        [ 0.2       ,  0.25145942],
#        [ 0.3       ,  0.24700638],
#        [ 0.1       ,  0.11170511],
#        [ 0.7       ,  0.16838866],
#        [ 0.125     ,  0.05895964],
#        [ 0.28333333,  0.32856687],
#        [ 1.        ,  0.96183782],
#        [ 1.        ,  0.80689355],
#        [ 0.4       ,  0.36615647],
#        [ 0.43333333,  0.0995827 ],
#        [ 0.        ,  0.11681365],
#        [ 0.        ,  0.1923209 ],
#        [ 0.25      ,  0.12280274],
#        [ 0.05357143,  0.16838866],
#        [ 0.        ,  0.13110257],
#        [ 0.8       ,  0.48445859],
#        [ 1.        ,  0.95128763],
#        [ 0.        ,  0.06729135],
#        [ 1.        ,  0.89447865],
#        [ 0.2       ,  0.25967539],
#        [ 0.3       ,  0.10616519],
#        [ 0.        ,  0.09950288],
#        [ 0.9       ,  0.91019957],
#        [ 0.7       ,  0.20269902],
#        [ 0.        ,  0.11943071],
#        [ 0.4       ,  0.77906839],
#        [ 0.        ,  0.11681365],
#        [ 0.13333333,  0.1676126 ],
#        [ 0.5       ,  0.15863344],
#        [ 0.1       ,  0.03624029],
#        [ 0.        ,  0.26580871],
#        [ 0.15297619,  0.11943071],
#        [ 0.2       ,  0.0995827 ],
#        [ 0.2       ,  0.0710897 ],
#        [ 0.14166667,  0.47167825],
#        [ 1.        ,  0.96689893],
#        [ 0.1       ,  0.08919559],
#        [ 0.5       ,  0.63349755],
#        [ 0.        ,  0.13110257],
#        [ 0.2       ,  0.46049764],
#        [ 0.        ,  0.09950288],
#        [ 1.        ,  0.93463329],
#        [ 0.9       ,  0.94972747],
#        [ 0.        ,  0.09538444],
#        [ 0.        ,  0.21282175],
#        [ 0.1       ,  0.17553312],
#        [ 0.6       ,  0.89066072],
#        [ 0.1       ,  0.08787451],
#        [ 1.        ,  0.95442674],
#        [ 0.        ,  0.09280331],
#        [ 0.06197552,  0.143781  ],
#        [ 0.5       ,  0.52678194],
#        [ 0.        ,  0.08507934],
#        [ 1.        ,  0.95080681],
#        [ 1.        ,  0.93463329],
#        [ 0.7       ,  0.14068034],
#        [ 1.        ,  0.96965914],
#        [ 0.375     ,  0.50290793],
#        [ 0.1       ,  0.12149639],
#        [ 0.2       ,  0.24744017],
#        [ 1.        ,  0.94972747],
#        [ 0.6       ,  0.30147238],
#        [ 0.1       ,  0.0895301 ],
#        [ 1.        ,  0.98060937],
#        [ 0.1       ,  0.07103592],
#        [ 0.50833333,  0.08940349],
#        [ 1.        ,  0.94252762],
#        [ 1.        ,  0.96023829],
#        [ 0.3       ,  0.21097936],
#        [ 0.06666667,  0.09950288],
#        [ 0.1       ,  0.11217123],
#        [ 0.2       ,  0.37286671],
#        [ 0.06197552,  0.143781  ],
#        [ 0.        ,  0.18579748],
#        [ 0.7       ,  0.32234323],
#        [ 0.2       ,  0.4893615 ],
#        [ 0.36666667,  0.11009826],
#        [ 1.        ,  0.9220133 ],
#        [ 0.1       ,  0.09298947],
#        [ 0.        ,  0.05996978],
#        [ 0.04519231,  0.14318713],
#        [ 0.2       ,  0.08305956],
#        [ 0.3       ,  0.32427697],
#        [ 0.9       ,  0.92112937],
#        [ 0.7       ,  0.43683629],
#        [ 0.        ,  0.05045418],
#        [ 0.2       ,  0.03418965],
#        [ 1.        ,  0.92267003],
#        [ 0.2       ,  0.16838866],
#        [ 1.        ,  0.95204363],
#        [ 0.1       ,  0.09298947],
#        [ 0.        ,  0.05942607],
#        [ 1.        ,  0.94667309],
#        [ 0.        ,  0.10038653],
#        [ 1.        ,  0.95974208],
#        [ 0.1       ,  0.21127663],
#        [ 0.2       ,  0.18378684],
#        [ 0.4       ,  0.14914084],
#        [ 0.        ,  0.08578511],
#        [ 0.3       ,  0.23161698],
#        [ 0.98571429,  0.64665111],
#        [ 0.9       ,  0.82498269],
#        [ 0.90738095,  0.74675676],
#        [ 0.9       ,  0.9608066 ],
#        [ 0.        ,  0.52602653],
#        [ 0.        ,  0.1226044 ],
#        [ 0.9       ,  0.96513322],
#        [ 0.        ,  0.05537313],
#        [ 0.        ,  0.1226044 ],
#        [ 0.8       ,  0.20043982]])

# %% [markdown]
# ## Предсказание моделей для стекинга. Способ 2
# Красивый с использованием метода cross_val_predict()

# %%
from sklearn.model_selection import cross_val_predict

def cross_val_predict_proba(estimator, X_train, y_train):
    kfold = KFold(n_splits=4, shuffle=True, random_state=None)
    return cross_val_predict(estimator, X_train, y_train, cv=kfold, method='predict_proba')

# TODO: подобрать гиперпараметры для ансамблей

# инициализирем модели с подобранными гиперпараметрами
rf_estimator = RandomForestClassifier()
gb_estimator = GradientBoostingClassifier()

# получаем предсказания вероятностей ансамблей на кросс-валидации для обучающей выборки
rf_train_pred = cross_val_predict_proba(rf_estimator, X_train, y_train)
gb_train_pred = cross_val_predict_proba(gb_estimator, X_train, y_train)

X_train_stack = np.stack([rf_train_pred[:, 1], gb_train_pred[:, 1]], axis=1)

# получаем предсказания ансамблей для тестовой выборки
rf_test_pred = rf_estimator.fit(X_train, y_train).predict_proba(X_test)
gb_test_pred = gb_estimator.fit(X_train, y_train).predict_proba(X_test)

X_test_stack = np.stack([rf_test_pred[:,1], gb_test_pred[:,1]], axis=1)

# %%
X_test_stack
# Out:
# array([[ 0.1       ,  0.04635935],
#        [ 0.2       ,  0.12779691],
#        [ 0.1       ,  0.13986669],
#        [ 0.6       ,  0.14068034],
#        [ 0.4       ,  0.4036792 ],
#        [ 0.2       ,  0.11170511],
#        [ 0.1       ,  0.24903108],
#        [ 0.1       ,  0.28030803],
#        [ 0.9       ,  0.90190717],
#        [ 0.        ,  0.08107034],
#        [ 0.        ,  0.09280331],
#        [ 0.        ,  0.07143607],
#        [ 1.        ,  0.933683  ],
#        [ 0.1       ,  0.12858014],
#        [ 1.        ,  0.86025295],
#        [ 1.        ,  0.9270053 ],
#        [ 0.3       ,  0.07317554],
#        [ 0.8       ,  0.16838866],
#        [ 0.5       ,  0.53839304],
#        [ 0.4       ,  0.37241087],
#        [ 0.6       ,  0.28427084],
#        [ 0.35      ,  0.49216374],
#        [ 1.        ,  0.94539501],
#        [ 0.5       ,  0.40325586],
#        [ 1.        ,  0.93250822],
#        [ 0.        ,  0.04924125],
#        [ 1.        ,  0.95974208],
#        [ 0.9       ,  0.16838866],
#        [ 0.65      ,  0.43061574],
#        [ 0.1       ,  0.17336078],
#        [ 0.        ,  0.05823568],
#        [ 0.        ,  0.1923209 ],
#        [ 0.4       ,  0.50726612],
#        [ 0.3       ,  0.25099956],
#        [ 0.3       ,  0.53977726],
#        [ 0.5       ,  0.16838866],
#        [ 0.1       ,  0.33989061],
#        [ 0.        ,  0.30641091],
#        [ 0.2       ,  0.10705655],
#        [ 0.47507937,  0.51538584],
#        [ 0.3       ,  0.07686773],
#        [ 0.71666667,  0.42756762],
#        [ 0.        ,  0.06766657],
#        [ 1.        ,  0.89145109],
#        [ 1.        ,  0.95523579],
#        [ 0.        ,  0.13276729],
#        [ 0.5       ,  0.17678256],
#        [ 0.05128968,  0.143781  ],
#        [ 1.        ,  0.95422915],
#        [ 0.2       ,  0.59789748],
#        [ 0.5       ,  0.25850309],
#        [ 0.4       ,  0.12899341],
#        [ 1.        ,  0.86211146],
#        [ 1.        ,  0.78778111],
#        [ 0.2       ,  0.17316565],
#        [ 0.        ,  0.09133075],
#        [ 0.        ,  0.07749877],
#        [ 0.        ,  0.11049537],
#        [ 0.        ,  0.11898301],
#        [ 1.        ,  0.9740206 ],
#        [ 0.025     ,  0.09222655],
#        [ 0.3       ,  0.15863344],
#        [ 0.        ,  0.09709363],
#        [ 0.7       ,  0.82838183],
#        [ 0.6       ,  0.60823808],
#        [ 0.9       ,  0.90368307],
#        [ 0.9       ,  0.74380762],
#        [ 0.        ,  0.10948046],
#        [ 0.1       ,  0.27698585],
#        [ 0.9       ,  0.89300695],
#        [ 0.67777778,  0.734608  ],
#        [ 0.        ,  0.08830799],
#        [ 0.2       ,  0.48892562],
#        [ 0.        ,  0.40744847],
#        [ 1.        ,  0.9740206 ],
#        [ 0.3       ,  0.38905539],
#        [ 0.        ,  0.1226044 ],
#        [ 0.6       ,  0.93709792],
#        [ 0.        ,  0.11865336],
#        [ 0.67777778,  0.734608  ],
#        [ 0.8       ,  0.92718677],
#        [ 0.3       ,  0.08564878],
#        [ 0.2       ,  0.24997971],
#        [ 0.        ,  0.09280331],
#        [ 0.4       ,  0.14521253],
#        [ 0.        ,  0.12149639],
#        [ 1.        ,  0.79078179],
#        [ 0.1       ,  0.32539677],
#        [ 0.95      ,  0.74675676],
#        [ 0.9       ,  0.93481995],
#        [ 0.2       ,  0.38076489],
#        [ 0.28666667,  0.09769756],
#        [ 0.9       ,  0.93138737],
#        [ 0.        ,  0.1226044 ],
#        [ 0.4       ,  0.21418987],
#        [ 0.        ,  0.09298947],
#        [ 0.9       ,  0.8920993 ],
#        [ 0.27333333,  0.14632917],
#        [ 0.3       ,  0.49552482],
#        [ 0.1       ,  0.14389292],
#        [ 1.        ,  0.9678034 ],
#        [ 0.1       ,  0.12652584],
#        [ 0.05128968,  0.143781  ],
#        [ 0.1       ,  0.12280274],
#        [ 0.9       ,  0.56405765],
#        [ 0.        ,  0.13176177],
#        [ 0.1       ,  0.14318713],
#        [ 0.05128968,  0.143781  ],
#        [ 0.1       ,  0.11835055],
#        [ 0.        ,  0.1038616 ],
#        [ 0.2       ,  0.05042036],
#        [ 0.98888889,  0.74675676],
#        [ 1.        ,  0.96727864],
#        [ 0.7       ,  0.87436889],
#        [ 1.        ,  0.96342488],
#        [ 0.2       ,  0.11984795],
#        [ 0.        ,  0.04662927],
#        [ 1.        ,  0.9068569 ],
#        [ 0.2       ,  0.49606288],
#        [ 0.9       ,  0.88589999],
#        [ 0.8       ,  0.90914033],
#        [ 0.        ,  0.14598608],
#        [ 1.        ,  0.96407349],
#        [ 0.        ,  0.08041879],
#        [ 0.05128968,  0.143781  ],
#        [ 0.5       ,  0.56042575],
#        [ 0.1       ,  0.09298947],
#        [ 0.8       ,  0.69484115],
#        [ 0.375     ,  0.11378152],
#        [ 0.        ,  0.11095555],
#        [ 0.3       ,  0.18867288],
#        [ 0.        ,  0.14233578],
#        [ 0.3       ,  0.1136253 ],
#        [ 0.04      ,  0.04742693],
#        [ 0.        ,  0.06425736],
#        [ 0.        ,  0.08830799],
#        [ 0.1       ,  0.29378586],
#        [ 0.        ,  0.13110257],
#        [ 0.        ,  0.31500906],
#        [ 0.14      ,  0.08161453],
#        [ 0.1       ,  0.06264714],
#        [ 0.9       ,  0.95346884],
#        [ 0.3       ,  0.218996  ],
#        [ 0.        ,  0.11775131],
#        [ 0.68333333,  0.42331732],
#        [ 0.4       ,  0.25376878],
#        [ 0.        ,  0.22236284],
#        [ 0.        ,  0.11095555],
#        [ 0.71666667,  0.42756762],
#        [ 0.        ,  0.11445398],
#        [ 1.        ,  0.96721923],
#        [ 0.        ,  0.143781  ],
#        [ 0.2       ,  0.05136264],
#        [ 0.4       ,  0.50017363],
#        [ 0.        ,  0.10345066],
#        [ 0.        ,  0.11049537],
#        [ 1.        ,  0.94224305],
#        [ 0.2       ,  0.4835994 ],
#        [ 0.68333333,  0.42331732],
#        [ 0.7       ,  0.5036295 ],
#        [ 1.        ,  0.7597685 ],
#        [ 0.9       ,  0.83891285],
#        [ 0.8       ,  0.90200021],
#        [ 0.2       ,  0.04407746],
#        [ 0.375     ,  0.11378152],
#        [ 0.4       ,  0.51072093],
#        [ 0.2       ,  0.43680829],
#        [ 0.2       ,  0.21351988],
#        [ 1.        ,  0.94273852],
#        [ 0.        ,  0.39508006],
#        [ 0.        ,  0.05895964],
#        [ 0.2       ,  0.29378586],
#        [ 0.        ,  0.10056546],
#        [ 0.06666667,  0.11943071],
#        [ 0.1       ,  0.32925807],
#        [ 1.        ,  0.93569837],
#        [ 0.9       ,  0.93418288],
#        [ 0.5       ,  0.41889695],
#        [ 1.        ,  0.94667032],
#        [ 0.9       ,  0.90874168],
#        [ 0.        ,  0.11865336],
#        [ 0.4       ,  0.46461641],
#        [ 1.        ,  0.93810256],
#        [ 0.05128968,  0.143781  ],
#        [ 1.        ,  0.9427918 ],
#        [ 0.        ,  0.11595692],
#        [ 1.        ,  0.90220398],
#        [ 0.2       ,  0.09332474],
#        [ 0.1       ,  0.06357947],
#        [ 0.        ,  0.11378152],
#        [ 0.        ,  0.13000345],
#        [ 0.1       ,  0.1561529 ],
#        [ 0.5       ,  0.3335799 ],
#        [ 0.        ,  0.04264624],
#        [ 0.7       ,  0.76142145],
#        [ 0.3       ,  0.07749877],
#        [ 0.5       ,  0.94841182],
#        [ 0.2       ,  0.50972441],
#        [ 0.        ,  0.09538444],
#        [ 0.1       ,  0.53290095],
#        [ 0.7       ,  0.77460833],
#        [ 0.6       ,  0.96157086],
#        [ 0.2       ,  0.19400841],
#        [ 0.9       ,  0.93939264],
#        [ 0.        ,  0.09538444],
#        [ 0.3       ,  0.22502971],
#        [ 0.26666667,  0.32277869],
#        [ 0.        ,  0.09538444],
#        [ 1.        ,  0.9016968 ],
#        [ 0.        ,  0.08830799],
#        [ 0.        ,  0.20163091],
#        [ 0.1       ,  0.04407746],
#        [ 0.        ,  0.28947982],
#        [ 0.2       ,  0.84695714],
#        [ 0.4       ,  0.61687149],
#        [ 0.        ,  0.22517728],
#        [ 1.        ,  0.74675676],
#        [ 0.6       ,  0.17852401],
#        [ 1.        ,  0.94286626],
#        [ 0.        ,  0.1226044 ],
#        [ 1.        ,  0.8304648 ],
#        [ 0.        ,  0.11095555],
#        [ 0.85      ,  0.8654484 ],
#        [ 0.4       ,  0.09298947],
#        [ 0.8       ,  0.84636558],
#        [ 0.4       ,  0.61674837],
#        [ 0.        ,  0.09298947],
#        [ 0.95      ,  0.74675676],
#        [ 0.1       ,  0.08995285],
#        [ 0.075     ,  0.13468658],
#        [ 0.1       ,  0.31723726],
#        [ 1.        ,  0.92537407],
#        [ 0.125     ,  0.07881553],
#        [ 0.        ,  0.143781  ],
#        [ 0.4       ,  0.39149902],
#        [ 0.        ,  0.09222655],
#        [ 0.5       ,  0.14688554],
#        [ 0.7       ,  0.16838866],
#        [ 0.9       ,  0.86561107],
#        [ 1.        ,  0.97685684],
#        [ 0.7       ,  0.83009426],
#        [ 1.        ,  0.94387961],
#        [ 0.1       ,  0.60670985],
#        [ 0.        ,  0.09280331],
#        [ 0.1       ,  0.11898301],
#        [ 0.1       ,  0.21229444],
#        [ 0.7       ,  0.89338678],
#        [ 0.        ,  0.26154193],
#        [ 0.9       ,  0.88589999],
#        [ 0.        ,  0.48779785],
#        [ 0.9       ,  0.92382854],
#        [ 0.1       ,  0.13835926],
#        [ 0.4       ,  0.31283186],
#        [ 0.        ,  0.10705655],
#        [ 0.3       ,  0.18260381],
#        [ 0.        ,  0.05895964],
#        [ 0.05128968,  0.143781  ],
#        [ 0.        ,  0.1226044 ],
#        [ 0.55      ,  0.87608409],
#        [ 0.1       ,  0.09298947],
#        [ 0.        ,  0.09349528],
#        [ 0.        ,  0.08830799],
#        [ 0.9       ,  0.90368307],
#        [ 0.8       ,  0.87106991],
#        [ 0.4       ,  0.07781196],
#        [ 0.        ,  0.09280331],
#        [ 0.        ,  0.04984001],
#        [ 0.        ,  0.05895964],
#        [ 0.1       ,  0.33989061],
#        [ 0.        ,  0.11170511],
#        [ 0.1       ,  0.25967539],
#        [ 0.05128968,  0.143781  ],
#        [ 1.        ,  0.95071325],
#        [ 0.9       ,  0.7648824 ],
#        [ 0.        ,  0.11943071],
#        [ 1.        ,  0.87913146],
#        [ 0.        ,  0.1055927 ],
#        [ 0.        ,  0.10452644],
#        [ 0.2       ,  0.11445398],
#        [ 0.        ,  0.09538444],
#        [ 0.        ,  0.30641091],
#        [ 0.7       ,  0.96606185],
#        [ 0.95      ,  0.74675676],
#        [ 0.1       ,  0.61222716],
#        [ 0.7       ,  0.74673841],
#        [ 0.        ,  0.06354079],
#        [ 0.        ,  0.08041879],
#        [ 0.6       ,  0.29218307],
#        [ 0.06666667,  0.11943071],
#        [ 0.        ,  0.1226044 ],
#        [ 0.1       ,  0.22236284],
#        [ 0.2       ,  0.04643762],
#        [ 0.06666667,  0.11943071],
#        [ 0.1       ,  0.28875737],
#        [ 0.2       ,  0.13901748],
#        [ 0.        ,  0.11681365],
#        [ 0.9       ,  0.95282152],
#        [ 0.1       ,  0.17336078],
#        [ 0.        ,  0.23731504],
#        [ 0.        ,  0.09280331],
#        [ 0.4       ,  0.11680812],
#        [ 0.2       ,  0.1035727 ],
#        [ 0.1       ,  0.09116075],
#        [ 0.1       ,  0.10705655],
#        [ 0.95      ,  0.74675676],
#        [ 0.9       ,  0.79962322],
#        [ 0.6       ,  0.21234428],
#        [ 0.7       ,  0.88979569],
#        [ 0.3       ,  0.25145942],
#        [ 0.1       ,  0.24700638],
#        [ 0.        ,  0.11170511],
#        [ 0.9       ,  0.16838866],
#        [ 0.        ,  0.05895964],
#        [ 0.17777778,  0.32856687],
#        [ 1.        ,  0.96183782],
#        [ 1.        ,  0.80689355],
#        [ 0.4       ,  0.36615647],
#        [ 0.33      ,  0.0995827 ],
#        [ 0.2       ,  0.11681365],
#        [ 0.        ,  0.1923209 ],
#        [ 0.1       ,  0.12280274],
#        [ 0.        ,  0.16838866],
#        [ 0.        ,  0.13110257],
#        [ 0.76666667,  0.48445859],
#        [ 1.        ,  0.95128763],
#        [ 0.        ,  0.06729135],
#        [ 1.        ,  0.89447865],
#        [ 0.        ,  0.25967539],
#        [ 0.3       ,  0.10616519],
#        [ 0.08      ,  0.09950288],
#        [ 1.        ,  0.91019957],
#        [ 0.7       ,  0.20269902],
#        [ 0.        ,  0.11943071],
#        [ 0.2       ,  0.77906839],
#        [ 0.2       ,  0.11681365],
#        [ 0.1       ,  0.1676126 ],
#        [ 0.7       ,  0.15863344],
#        [ 0.        ,  0.03624029],
#        [ 0.1       ,  0.26580871],
#        [ 0.06666667,  0.11943071],
#        [ 0.15      ,  0.0995827 ],
#        [ 0.2       ,  0.0710897 ],
#        [ 0.19333333,  0.29525013],
#        [ 1.        ,  0.96689893],
#        [ 0.2       ,  0.08919559],
#        [ 0.8       ,  0.63349755],
#        [ 0.        ,  0.13110257],
#        [ 0.4       ,  0.46049764],
#        [ 0.        ,  0.09950288],
#        [ 0.9       ,  0.93463329],
#        [ 1.        ,  0.94972747],
#        [ 0.        ,  0.09538444],
#        [ 0.        ,  0.21282175],
#        [ 0.        ,  0.17553312],
#        [ 0.8       ,  0.89066072],
#        [ 0.1       ,  0.08787451],
#        [ 1.        ,  0.95442674],
#        [ 0.        ,  0.09280331],
#        [ 0.05128968,  0.143781  ],
#        [ 0.6       ,  0.52678194],
#        [ 0.        ,  0.08507934],
#        [ 1.        ,  0.95080681],
#        [ 0.9       ,  0.93463329],
#        [ 0.6       ,  0.14068034],
#        [ 1.        ,  0.96965914],
#        [ 0.37333333,  0.32191615],
#        [ 0.        ,  0.12149639],
#        [ 0.3       ,  0.24744017],
#        [ 1.        ,  0.94972747],
#        [ 0.6       ,  0.30147238],
#        [ 0.1       ,  0.0895301 ],
#        [ 1.        ,  0.98060937],
#        [ 0.        ,  0.07103592],
#        [ 0.44166667,  0.08940349],
#        [ 1.        ,  0.94252762],
#        [ 0.9       ,  0.96023829],
#        [ 0.2       ,  0.21097936],
#        [ 0.18      ,  0.09950288],
#        [ 0.        ,  0.11217123],
#        [ 0.2       ,  0.37286671],
#        [ 0.05128968,  0.143781  ],
#        [ 0.        ,  0.18579748],
#        [ 0.6       ,  0.32234323],
#        [ 0.2       ,  0.4893615 ],
#        [ 0.25      ,  0.11009826],
#        [ 1.        ,  0.9220133 ],
#        [ 0.        ,  0.09298947],
#        [ 0.03333333,  0.05996978],
#        [ 0.12986111,  0.14318713],
#        [ 0.1       ,  0.08305956],
#        [ 0.2       ,  0.32427697],
#        [ 1.        ,  0.92112937],
#        [ 0.5       ,  0.43683629],
#        [ 0.03333333,  0.05045418],
#        [ 0.        ,  0.03418965],
#        [ 1.        ,  0.92267003],
#        [ 0.1       ,  0.16838866],
#        [ 1.        ,  0.95204363],
#        [ 0.        ,  0.09298947],
#        [ 0.        ,  0.05942607],
#        [ 1.        ,  0.94667309],
#        [ 0.        ,  0.10038653],
#        [ 1.        ,  0.95974208],
#        [ 0.2       ,  0.21127663],
#        [ 0.2       ,  0.18378684],
#        [ 0.48      ,  0.14914084],
#        [ 0.075     ,  0.08578511],
#        [ 0.2       ,  0.23161698],
#        [ 1.        ,  0.64665111],
#        [ 0.7       ,  0.82498269],
#        [ 0.95      ,  0.74675676],
#        [ 1.        ,  0.9608066 ],
#        [ 0.        ,  0.52602653],
#        [ 0.        ,  0.1226044 ],
#        [ 1.        ,  0.96513322],
#        [ 0.        ,  0.05537313],
#        [ 0.        ,  0.1226044 ],
#        [ 0.4       ,  0.20043982]])

# %% [markdown]
# ## Объединяем предсказания ансамблей с помощью логистической регрессии

# %%
from sklearn.linear_model import LogisticRegression

# TODO: подобрать гиперпараметры LogisticRegression

logreg = LogisticRegression().fit(X_train_stack, y_train)
predicted = logreg.predict(X_test_stack)

# %% [markdown]
# ## Формируем файл для отправки

# %%
with open('submission.txt', 'w') as out:
    out.write('PassengerId,Survived\n')
    for passenger, y in zip(test['PassengerId'], predicted):
        out.write('%s,%s\n' % (passenger, y))
