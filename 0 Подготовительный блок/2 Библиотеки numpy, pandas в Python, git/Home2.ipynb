# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv( 'Mountains.csv', delimiter = ',' )
data.head(5)
# Out:
#    Rank                                  Mountain  Height (m)  Height (ft)  \
# 0     1  Mount Everest / Sagarmatha / Chomolungma        8848        29029
# 1     2                K2 / Qogir / Godwin Austen        8611        28251
# 2     3                             Kangchenjunga        8586        28169
# 3     4                                    Lhotse        8516        27940
# 4     5                                    Makalu        8485        27838
#
#    Prominence (m)                   Range              Coordinates  \
# 0            8848     Mahalangur Himalaya  27°59′17″N 86°55′31″E﻿
# 1            4017       Baltoro Karakoram  35°52′53″N 76°30′48″E﻿
# 2            3922  Kangchenjunga Himalaya  27°42′12″N 88°08′51″E﻿
# 3             610     Mahalangur Himalaya  27°57′42″N 86°55′59″E﻿
# 4            2386     Mahalangur Himalaya  27°53′23″N 87°05′20″E﻿
#
#   Parent mountain First ascent Ascents bef. 2004  Failed attempts bef. 2004
# ...

# %%
# рисуем в браузере
# %matplotlib inline

# %%
data.hist( column = ['Height (m)'] )
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000B81BEA2BE0>]], dtype=object)

# %%
#data.to_csv( 'Mountains_modified.csv', sep = ';', na_rep = '0', columns = ['Rank', 'Mountain', 'Parent mountain'], index = True )

# %%
df_count_mountain_in_parent_mountain = data.groupby('Parent mountain')[['Mountain']].count()\
    .sort_values('Mountain', ascending=False).head(100)
    
df_count_mountain_in_parent_mountain
# Out:
#                     Mountain
# Parent mountain
# Mount Everest              9
# Gasherbrum I               8
# Kangchenjunga              7
# Cho Oyu                    7
# K2                         5
# Distaghil Sar              5
# Dhaulagiri                 4
# Shisha Pangma              4
# Manaslu                    3
# Dhaulagiri IV              3
# Batura Sar                 3
# Teram Kangri I             3
# Khunyang Chhish            3
# Kamet                      3
# Saltoro Kangri             2
# Malubiting                 2
# Saser Kangri I             2
# Nanda Devi                 2
# Annapurna I                2
# Kongur Tagh                2
# Lhotse                     2
# Skil Brum                  2
# Gangkhar Puensum           2
# Gangkar Puensum            2
# Chogolisa                  2
# Noshaq                     2
# Shispare                   1
# Pumari Chhish              1
# Shishapangma               1
# Skil Brum (K2)             1
# ...

# %%
mask = df_count_mountain_in_parent_mountain[ lambda Mountain : Mountain > 3 ]

# %%
mask
# Out:
#                  Mountain
# Parent mountain
# Mount Everest         9.0
# Gasherbrum I          8.0
# Kangchenjunga         7.0
# Cho Oyu               7.0
# K2                    5.0
# Distaghil Sar         5.0
# Dhaulagiri            4.0
# Shisha Pangma         4.0
# Manaslu               NaN
# Dhaulagiri IV         NaN
